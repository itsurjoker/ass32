# %% [raw]
# #Q1.
#
# Both t-tests and z-tests are statistical tests used to make inferences about population parameters based on sample data. They are commonly used in hypothesis testing to determine whether there is a significant difference between sample means or proportions and their corresponding population parameters. The main difference between these tests lies in the assumptions about the population and the sample size.
#
# T-test:
# A t-test is used when the sample size is small (typically less than 30) or when the population standard deviation is unknown. There are two main types of t-tests: the one-sample t-test, the independent two-sample t-test, and the paired-sample t-test.
#
# Example scenario for a t-test:
# Imagine you are a researcher testing a new drug's effectiveness in reducing blood pressure. You measure the blood pressure of a group of 15 participants before and after administering the drug. You want to determine whether there's a significant difference in blood pressure before and after taking the drug.
#
# In this case, you would use a paired-sample t-test because you're comparing the same group of participants before and after treatment. The small sample size and the unknown population standard deviation make the t-test appropriate for this situation.
#
# Z-test:
# A z-test is used when the sample size is large (typically more than 30) and the population standard deviation is known. Z-tests are often used for testing hypotheses related to proportions.
#
# Example scenario for a z-test:
# Suppose you're working for a company that produces light bulbs, and they claim that their light bulbs have a mean lifespan of 1000 hours. You decide to randomly select a sample of 100 light bulbs and test their lifespans. You want to determine whether the company's claim is supported by the data.
#
# Since the sample size is relatively large (100) and you're dealing with a population mean, you can use a z-test, assuming that the population standard deviation is known (which is often an approximation). This test will help you decide whether the sample mean differs significantly from the claimed population mean of 1000 hours.
#
# In summary, the choice between a t-test and a z-test depends on factors such as sample size and whether the population standard deviation is known. If the sample size is small or the population standard deviation is unknown, a t-test is appropriate. If the sample size is large and the population standard deviation is known (or can be reasonably estimated), a z-test can be used.

# %% [raw]
# #Q2.
#
#
# In statistics, one-tailed and two-tailed tests are types of hypothesis tests used to determine whether there is enough evidence to reject a null hypothesis in favor of an alternative hypothesis. These tests are commonly used to make inferences about population parameters based on sample data. The main difference between one-tailed and two-tailed tests lies in the directionality of the hypothesis being tested and the corresponding critical region.
#
#     One-Tailed Test:
#     In a one-tailed test, the alternative hypothesis specifies a specific direction of the effect or relationship being tested. There are two possible types of one-tailed tests:
#
#         Upper-Tailed Test: In this type of test, the alternative hypothesis focuses on the possibility of a value being greater than a certain threshold. The critical region is located in the upper tail of the distribution of the test statistic.
#
#         Lower-Tailed Test: Here, the alternative hypothesis is concerned with the possibility of a value being smaller than a certain threshold. The critical region is located in the lower tail of the distribution.
#
#     One-tailed tests are appropriate when you have a specific directional hypothesis, and you're only interested in detecting an effect in that specific direction. This can be useful when you have prior knowledge or a clear theoretical basis for expecting an effect to occur in one direction.
#
#     Two-Tailed Test:
#     In a two-tailed test, the alternative hypothesis is generally that there is a difference or effect, without specifying a particular direction. The critical region is divided between both tails of the distribution, representing the possibility of observing extreme values in either direction.
#
#     Two-tailed tests are used when you're interested in determining whether there is a significant difference or effect in either direction. This is often the case when you don't have a specific expectation about the direction of the effect, or when you want to be cautious about overlooking a potential effect that might occur in the opposite direction.
#
# To summarize:
#
#     One-tailed tests are used when you have a specific directional hypothesis and are interested in effects in a single direction.
#     Two-tailed tests are used when you are interested in detecting a significant difference or effect, regardless of the direction.
#
# Choosing between these types of tests depends on your research question, prior knowledge, and the nature of the data you're working with. The decision should be guided by the underlying theory and the objectives of your analysis.

# %% [raw]
# #Q3.
#
# Type 1 and Type 2 errors are terms used in hypothesis testing to describe the potential mistakes or errors that can occur when making decisions based on statistical tests. These errors are associated with the acceptance or rejection of a null hypothesis in relation to an alternative hypothesis. Here's an explanation of both types of errors along with example scenarios:
#
#     Type 1 Error (False Positive):
#         A Type 1 error occurs when you reject a true null hypothesis. In other words, you conclude that there is an effect or difference when there actually isn't one in the population.
#         The probability of committing a Type 1 error is denoted by the symbol "alpha" (α), and it's also called the significance level of the test.
#         Researchers often set the significance level before conducting the test. Common values for alpha include 0.05 or 0.01.
#         Type 1 errors are considered more serious in situations where the consequences of an incorrect rejection of the null hypothesis are significant.
#
# Example Scenario for Type 1 Error:
# Imagine a pharmaceutical company testing a new drug for its effectiveness in reducing blood pressure. The null hypothesis (H0) is that the drug has no effect on blood pressure, while the alternative hypothesis (Ha) is that the drug does reduce blood pressure. If the researchers perform a study and mistakenly conclude that the drug is effective (reject H0) when it actually has no effect in the population, this would be a Type 1 error.
#
#     Type 2 Error (False Negative):
#         A Type 2 error occurs when you fail to reject a false null hypothesis. In other words, you fail to identify an effect or difference that does exist in the population.
#         The probability of committing a Type 2 error is denoted by the symbol "beta" (β).
#         Type 2 errors are influenced by factors such as sample size and the effect size (magnitude of the difference you're trying to detect).
#         In scenarios where the consequences of missing a true effect are significant, Type 2 errors are a concern.
#
# Example Scenario for Type 2 Error:
# Continuing with the pharmaceutical example, let's say the researchers fail to find a significant difference in blood pressure reduction between the new drug and a placebo (fail to reject H0), even though the drug actually does have a small but meaningful effect on blood pressure in the population. In this case, a Type 2 error has occurred because the researchers missed identifying the effect of the drug due to various factors like small sample size or insufficient statistical power.
#
# In summary, Type 1 and Type 2 errors represent the trade-off between making errors in hypothesis testing. Researchers must carefully consider the consequences of both types of errors and choose appropriate significance levels, sample sizes, and study designs to minimize the risk of making incorrect conclusions based on their statistical analyses.

# %% [raw]
# #Q4.
#
# Bayes's Theorem is a fundamental concept in probability theory and statistics that allows us to update our beliefs or probabilities about an event based on new evidence. It is named after the Reverend Thomas Bayes, who developed the theorem in the 18th century. The theorem is especially useful in situations where we have prior knowledge and want to incorporate new information to make more accurate predictions.
#
# The formula for Bayes's Theorem is:
#
# P(A|B)=P(B|A)⋅P(A)/P(B)
#
# Where:
#
#     P(A∣B)P(A∣B) is the probability of event A occurring given that event B has occurred.
#     P(B∣A)P(B∣A) is the probability of event B occurring given that event A has occurred.
#     P(A)P(A) is the prior probability of event A occurring.
#     P(B)P(B) is the probability of event B occurring.
#
# Let's break down Bayes's Theorem with a classic example: medical testing.
#
# Suppose we have a patient who wants to know if they have a certain rare disease. Let's call this disease "Disease X". The patient decides to take a medical test for the disease, and the test result comes back positive. We want to use Bayes's Theorem to calculate the probability that the patient actually has Disease X, given the positive test result.
#
#     P(A)P(A): This represents the prior probability of having Disease X. Let's say that in the general population, only 1 in 1000 people have Disease X, so P(A)=0.001P(A)=0.001.
#
#     P(B∣A)P(B∣A): This is the probability of getting a positive test result given that the patient actually has Disease X. The accuracy of the test is not perfect, and it gives a positive result 95% of the time for people who have the disease, so P(B∣A)=0.95P(B∣A)=0.95.
#
#     P(B)P(B): This is the probability of getting a positive test result, regardless of whether the patient has the disease. It takes into account both true positives (people with the disease who test positive) and false positives (people without the disease who test positive). This can be calculated using the formula:
#     P(B)=P(B∣A)⋅P(A)+P(B∣¬A)⋅P(¬A)P(B)=P(B∣A)⋅P(A)+P(B∣¬A)⋅P(¬A)
#     Since P(¬A)P(¬A), the probability of not having the disease, is 1−P(A)1−P(A) and P(B∣¬A)P(B∣¬A), the probability of a positive test result given no disease, might be, for example, 5%, P(B)P(B) can be calculated.
#
# Now, we can plug all these values into Bayes's Theorem to calculate P(A∣B)P(A∣B), the probability that the patient has Disease X given a positive test result.
#
# Keep in mind that Bayes's Theorem is a powerful tool for updating probabilities based on new evidence, and it has applications in various fields beyond medical testing, such as machine learning, finance, and more.

# %% [raw]
# #Q5.
#
# A confidence interval is a statistical range that provides an estimate of the plausible range of values within which a population parameter, such as a population mean or population proportion, is likely to fall. It reflects the uncertainty associated with the estimation process, taking into account the variability of the sample data. In other words, it gives us a sense of how confident we can be that the true population parameter lies within a certain range.
#
# Confidence intervals are typically expressed as a range of values, along with a level of confidence. The level of confidence is often denoted as a percentage, such as 95% or 99%. A 95% confidence interval, for example, implies that if we were to draw multiple samples from the same population and compute confidence intervals for each sample, approximately 95% of these intervals would contain the true population parameter.
#
# Here's how to calculate a confidence interval, using the example of calculating a confidence interval for the population mean:
#
#     Collect Sample Data: Gather a random sample of data from the population of interest. Let's say we're interested in estimating the average height of a certain species of trees.
#
#     Calculate Sample Statistics: Compute the sample mean (x̄) and sample standard deviation (s) from the collected data.
#
#     Choose a Confidence Level: Decide on the level of confidence you want. Let's say we choose a 95% confidence level.
#
#     Determine the Z-Score or T-Score: The formula for the confidence interval depends on whether you know the population standard deviation (Z-score) or not (t-score). If the sample size is large (typically > 30) and the population standard deviation is known, you can use the Z-score. If not, you'll use the t-score. For this example, let's use the t-score.
#
#     Calculate the Margin of Error: The margin of error (ME) accounts for the variability in the sample and is calculated as:
#
#     ME = t * (s / √n)
#
#     where t is the critical t-score from the t-distribution corresponding to your chosen confidence level and degrees of freedom, s is the sample standard deviation, and n is the sample size.
#
#     Calculate the Confidence Interval: The confidence interval is calculated as:
#
#     Confidence Interval = x̄ ± ME
#
# Now, let's put this into an example:
#
# Suppose we have measured the heights of 40 trees from a specific forest and found that the sample mean height is 220 cm, and the sample standard deviation is 15 cm. We want to calculate a 95% confidence interval for the average height of all trees in the forest.
#
#     Sample Mean (x̄) = 220 cm
#     Sample Standard Deviation (s) = 15 cm
#     Sample Size (n) = 40
#     Confidence Level = 95%
#
# Using a t-table or calculator, for a 95% confidence level with 39 degrees of freedom (n - 1), the critical t-score is approximately 2.021.
#
# Margin of Error (ME) = 2.021 * (15 / √40) ≈ 4.52 cm
#
# Confidence Interval = 220 ± 4.52 = (215.48, 224.52) cm
#
# Therefore, we can be 95% confident that the true average height of all trees in the forest lies between 215.48 cm and 224.52 cm.

# %% [raw]
# #Q6.
#
# Certainly! Bayes' Theorem is a mathematical formula used to update the probability of an event based on new evidence. The formula is as follows:
#
# P(A|B)=P(B|A)⋅P(A)/P(B)
#
# Where:
#
#     P(A∣B)P(A∣B) is the probability of event A occurring given the new evidence B.
#     P(B∣A)P(B∣A) is the probability of the new evidence B occurring given that event A has occurred.
#     P(A)P(A) is the prior probability of event A occurring.
#     P(B)P(B) is the probability of the new evidence B occurring.
#
# Let's go through a sample problem to understand how to use Bayes' Theorem.
#
# Sample Problem: Medical Test
# Suppose you are a doctor and you have a patient who is exhibiting certain symptoms that could be indicative of a rare disease. The disease occurs in only 1% of the population (P(A)=0.01P(A)=0.01), and there's a test for this disease. The test is 95% accurate, meaning that it correctly detects the disease 95% of the time and has a 5% false positive rate (P(B∣A)=0.95P(B∣A)=0.95 and P(B∣¬A)=0.05P(B∣¬A)=0.05).
#
# You administer the test to your patient, and it comes back positive. What's the updated probability that your patient actually has the disease?
#
# Solution:
# In this case, we want to find P(A∣B)P(A∣B), the probability that the patient has the disease given that the test is positive.
#
# Using Bayes' Theorem:
# P(A|B)=P(B|A)⋅P(A)/P(B)
#
# We need to calculate P(B)P(B), the probability of getting a positive test result, which can happen either if the patient has the disease and the test is positive (P(A)⋅P(B∣A)P(A)⋅P(B∣A)) or if the patient doesn't have the disease but the test is a false positive (P(¬A)⋅P(B∣¬A)P(¬A)⋅P(B∣¬A)).
#
# P(B)=P(A)⋅P(B∣A)+P(¬A)⋅P(B∣¬A)P(B)=P(A)⋅P(B∣A)+P(¬A)⋅P(B∣¬A)
# P(B)=0.01⋅0.95+0.99⋅0.05P(B)=0.01⋅0.95+0.99⋅0.05
# P(B)=0.0495+0.0495=0.099P(B)=0.0495+0.0495=0.099
#
# Now we can plug this into the Bayes' Theorem formula:
# P(A|B)=P(B|A)⋅P(A)/P(B)
# P(A|B)=0.95⋅0.01/0.099
# P(A|B)≈0.9596
#
# So, even with a positive test result, the updated probability that the patient actually has the disease is about 0.9596 or approximately 95.96%.

# %% [raw]
# #Q7.
#
# To calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5, we'll use the formula for the confidence interval:
#
# Confidence Interval = Mean ± (Critical Value) * (Standard Deviation / √(Sample Size))
#
# The critical value for a 95% confidence interval when using a normal distribution is approximately 1.96.
#
# Given:
# Mean (μ) = 50
# Standard Deviation (σ) = 5
# Sample Size (n) = You need to provide this value
#
# Let's say the sample size is n = 100 (you can replace this with your actual sample size if different):
#
# Confidence Interval = 50 ± (1.96) * (5 / √100)
# Confidence Interval = 50 ± 0.98
# Confidence Interval = (49.02, 50.98)
#
# Interpretation:
# The 95% confidence interval for the population mean lies between 49.02 and 50.98. This means that if we were to repeatedly take different samples from the same population and calculate their confidence intervals, approximately 95% of those intervals would contain the true population mean. In other words, we are 95% confident that the true population mean falls within this interval.

# %% [raw]
# #Q8.
#
#
# The margin of error is a statistical concept used to quantify the range within which a true population parameter is likely to fall based on a sample taken from that population. It's often used in the context of constructing confidence intervals, which are ranges of values that are likely to contain the true population parameter with a certain level of confidence.
#
# The margin of error represents the maximum amount by which the estimate derived from the sample might differ from the actual population parameter. It's typically expressed as a percentage or a fixed value and is related to the level of confidence chosen for the interval (e.g., 95% confidence interval).
#
# Sample size plays a crucial role in determining the margin of error. Generally, as the sample size increases, the margin of error decreases. This is because larger sample sizes provide more information about the population, leading to more precise estimates. When you have a larger sample size, the variability in the sample estimates is reduced, resulting in a narrower confidence interval and a smaller margin of error.
#
# Here's an example to illustrate this:
#
# Let's say you're interested in estimating the average height of students in a particular school. You decide to take two different sample sizes: one with 50 students and another with 500 students. You construct 95% confidence intervals for both samples.
#
# For the sample of 50 students, the margin of error might be around ±2 inches. This means that you're 95% confident that the true average height of all students in the school falls within 2 inches above or below the sample average.
#
# For the sample of 500 students, the margin of error might be reduced to ±0.5 inches. With the larger sample size, you're more confident that the sample average accurately reflects the true average height of all students, hence the narrower margin of error.
#
# In summary, a larger sample size leads to a smaller margin of error because it reduces the uncertainty associated with estimating population parameters based on a sample.

# %% [raw]
# #Q9.
#
#
# The z-score, also known as the standard score, is a measure that tells you how many standard deviations a data point is away from the mean of the population. It is calculated using the formula:
#
# z=x−μ/σ
#
# Where:
#
#     xx is the value of the data point (75 in this case)
#     μμ is the mean of the population (70 in this case)
#     σσ is the standard deviation of the population (5 in this case)
#     zz is the z-score
#
# Plugging in the values:
#
# z=75−70/5=5/5=1
#
# Interpretation:
# A z-score of 1 means that the data point (75) is 1 standard deviation above the mean (70) of the population. In other words, this data point is slightly higher than the average value of the population by one standard deviation. This can give you an idea of how "unusual" or "typical" the data point is in relation to the rest of the population. A positive z-score indicates that the data point is above the mean, while a negative z-score would indicate that the data point is below the mean.

# %% [raw]
# #Q10.
#
# To conduct a hypothesis test using a t-test to determine if the new weight loss drug is significantly effective, we need to set up the null and alternative hypotheses and then perform the calculations. Here's how you can do it:
#
# Null Hypothesis (H0): The new weight loss drug is not significantly effective. The population mean weight loss is equal to or greater than 0 pounds.
# Alternative Hypothesis (Ha): The new weight loss drug is significantly effective. The population mean weight loss is less than 0 pounds.
#
# Given that you have a sample size of 50 participants, an average weight loss of 6 pounds, and a standard deviation of 2.5 pounds, we can calculate the t-statistic using the following formula:
#
# t=xˉ−μ0/(s/n)
#
#
#
# Where:
#
#     xˉxˉ is the sample mean weight loss (6 pounds),
#     μ0μ0​ is the hypothesized population mean weight loss (0 pounds),
#     ss is the sample standard deviation (2.5 pounds), and
#     nn is the sample size (50 participants).
#
# Plugging in the values:
#
# t=6−0/(2.5/50)
#
#
#
# Calculating this gives us the t-statistic. Once we have the t-statistic, we can compare it to the critical t-value from the t-distribution table for a one-tailed test at a 95% confidence level with degrees of freedom n−1n−1 (49 degrees of freedom in this case).
#
# If the calculated t-statistic is smaller than the critical t-value, we can reject the null hypothesis and conclude that the new weight loss drug is significantly effective.
#
# Keep in mind that this calculation assumes that the sample is randomly selected and that the weight loss data is normally distributed. If these assumptions are not met, the results of the hypothesis test might not be reliable. Additionally, the p-value associated with the t-statistic can also be used to determine significance, and more advanced statistical software can perform these calculations more precisely.

# %% [raw]
# #Q11.
#
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job, you can use the following formula:
#
# Confidence Interval = Sample Proportion ± Z * (sqrt((Sample Proportion * (1 - Sample Proportion)) / Sample Size))
#
# Where:
#
#     Sample Proportion = 65% (0.65 as a decimal)
#     Z = Z-score corresponding to the desired confidence level (95% confidence level corresponds to a Z-score of approximately 1.96)
#     Sample Size = 500
#
# Let's plug in the values and calculate the confidence interval:
#
# Sample Proportion = 0.65
# Z = 1.96 (for a 95% confidence level)
# Sample Size = 500
#
# Confidence Interval = 0.65 ± 1.96 * (sqrt((0.65 * (1 - 0.65)) / 500))
#
# Now, let's calculate:
#
# Confidence Interval = 0.65 ± 1.96 * (sqrt((0.65 * 0.35) / 500))
# Confidence Interval = 0.65 ± 1.96 * (sqrt(0.2275 / 500))
# Confidence Interval = 0.65 ± 1.96 * 0.030140
#
# Confidence Interval = 0.65 ± 0.059067
#
# So, the 95% confidence interval for the true proportion of people who are satisfied with their job is approximately 0.591 (59.1%) to 0.709 (70.9%). This means that we can be 95% confident that the true proportion of satisfied individuals falls within this range based on the survey results.

# %% [raw]
# #Q12.
#
#
# To conduct a hypothesis test to determine if there is a significant difference in student performance between the two teaching methods, we can use a two-sample t-test. The null hypothesis (H0) assumes that there is no significant difference between the teaching methods, while the alternative hypothesis (Ha) assumes that there is a significant difference.
#
# Null Hypothesis (H0): The two teaching methods have no significant difference in student performance.
# Alternative Hypothesis (Ha): The two teaching methods have a significant difference in student performance.
#
# Given the information, we have:
#
# Sample A:
#
#     Mean (μA) = 85
#     Standard Deviation (σA) = 6
#     Sample Size (nA) = ?
#
# Sample B:
#
#     Mean (μB) = 82
#     Standard Deviation (σB) = 5
#     Sample Size (nB) = ?
#
# We're missing the sample sizes for both groups. The sample sizes are crucial for calculating the degrees of freedom and for performing the t-test. Please provide the sample sizes for samples A and B so that we can proceed with the calculations and hypothesis test.

# %% [raw]
# #Q13.
#
# To calculate the confidence interval for the true population mean, you can use the formula for the confidence interval:
#
# Confidence Interval = Sample Mean ± Margin of Error
#
# Where the Margin of Error is determined by the critical value (z) for the desired confidence level and the standard error of the sample mean.
#
# Given information:
#
#     Population Mean (μ): 60
#     Population Standard Deviation (σ): 8
#     Sample Mean (x̄): 65
#     Sample Size (n): 50
#     Confidence Level: 90% (which corresponds to a z-score of 1.645)
#
# First, calculate the standard error (SE) of the sample mean:
#
# Standard Error (SE) = Population Standard Deviation / √Sample Size
# SE = 8 / √50 ≈ 1.131
#
# Next, calculate the Margin of Error (MOE):
#
# Margin of Error (MOE) = z * SE
# MOE = 1.645 * 1.131 ≈ 1.864
#
# Now, construct the confidence interval:
#
# Confidence Interval = Sample Mean ± Margin of Error
# CI = 65 ± 1.864
#
# The confidence interval for the true population mean at 90% confidence level is approximately:
# CI = (63.136, 66.864)
#
# So, you can say with 90% confidence that the true population mean lies between 63.136 and 66.864.

# %% [raw]
# #Q14.
#
# To conduct a hypothesis test to determine if caffeine has a significant effect on reaction time, we need to set up the null and alternative hypotheses and then calculate the t-statistic and p-value using the given information.
#
# Hypotheses:
#
# Null Hypothesis (H0): Caffeine has no significant effect on reaction time.
# Alternative Hypothesis (Ha): Caffeine has a significant effect on reaction time.
#
# Given Information:
#
# Sample size (n) = 30
# Sample mean (x̄) = 0.25 seconds
# Sample standard deviation (s) = 0.05 seconds
# Confidence level = 90% (α = 0.10)
#
# Calculations:
#
#     Calculate the standard error of the mean (SE):
#
#     SE = s / √n
#     SE = 0.05 / √30
#     SE ≈ 0.009144
#
#     Calculate the t-statistic:
#
#     t = (x̄ - μ) / SE
#
#     Where μ is the hypothesized population mean (under the null hypothesis). Since the null hypothesis states that there is no effect of caffeine, μ = 0.25 (sample mean).
#
#     t = (0.25 - 0) / 0.009144
#     t ≈ 27.31
#
#     Calculate the degrees of freedom (df):
#
#     df = n - 1
#     df = 30 - 1
#     df = 29
#
#     Find the critical t-value for a one-tailed test at a 90% confidence level:
#
#     Using a t-table or calculator, the critical t-value at α = 0.10 and df = 29 is approximately 1.645.
#
#     Compare the calculated t-statistic with the critical t-value:
#
#     Since the calculated t-statistic (27.31) is much larger than the critical t-value (1.645), we can reject the null hypothesis.
#
#     Calculate the p-value:
#
#     Using a t-distribution calculator or software, you can find the p-value associated with a t-statistic of 27.31 and df = 29. The p-value is extremely small, close to 0.
#
# Conclusion:
#
# Since the p-value is much smaller than the significance level (α = 0.10), we reject the null hypothesis. This means that there is strong evidence to suggest that caffeine has a significant effect on reaction time at a 90% confidence level.
